# %%
import torch

with open('wizard_of_oz.txt', 'r', encoding = "utf-8") as f:
    text = f.read()
chars = sorted(set(text))
print(set(text))
# print('----------------')
# print(chars)
# Out:
# {'\n', 'T', 'R', 'v', 'I', 'z', '“', 'Z', '$', 'x', '•', 'U', 'A', '—', '*', '’', '\ufeff', '_', '™', ']', 'F', 'H', '[', 'q', '1', 'y', 'K', '4', 'm', 'l', 'Q', 'u', 'B', '9', '/', '-', '%', 'c', '&', 'n', '.', ',', '8', '7', ' ', 's', '6', 'N', 'M', '#', '0', 'X', 'o', 'j', 'r', "'", 'b', '(', 't', 'w', 'e', '?', 'C', 'G', '”', 'a', 'S', 'd', 'P', '3', 'k', 'h', 'f', 'V', 'D', 'Y', '2', 'J', '"', '!', ';', 'E', 'L', 'p', '‘', 'g', '5', 'O', 'W', 'i', ')', ':'}

# %%
string_to_int = { ch:i for i, ch in enumerate(chars) }
int_to_string = { ch:i for ch, i in enumerate(chars) }
encode = lambda s: [string_to_int[c] for c in s]
decode = lambda I: "".join([int_to_string[i] for i in I])

# %%
encode('hello')
# Out:
# [65, 62, 69, 69, 72]

# %%
data = torch.tensor(encode(text), dtype = torch.long)
print(data[:100])
# Out:
# tensor([91, 48, 65, 62,  1, 44, 75, 72, 67, 62, 60, 77,  1, 35, 78, 77, 62, 71,
#         59, 62, 75, 64,  1, 62, 30, 72, 72, 68,  1, 72, 63,  1, 32, 72, 75, 72,
#         77, 65, 82,  1, 58, 71, 61,  1, 77, 65, 62,  1, 51, 66, 83, 58, 75, 61,
#          1, 66, 71,  1, 43, 83,  0,  1,  1,  1,  1,  0, 48, 65, 66, 76,  1, 62,
#         59, 72, 72, 68,  1, 66, 76,  1, 63, 72, 75,  1, 77, 65, 62,  1, 78, 76,
#         62,  1, 72, 63,  1, 58, 71, 82, 72, 71])

# %%
n = int(0.8 * len(data))
train_data = data[:n]
val_data = data[n:]

# %%
block_size = 8

x = train_data[:block_size]
y = train_data[1:block_size + 1]

for t in range(block_size):
    context = x[:t + 1]
    target = y[t]
    print(f"when the input is {context} target is {target}")
# Out:
# when the input is tensor([91]) target is 48
# when the input is tensor([91, 48]) target is 65
# when the input is tensor([91, 48, 65]) target is 62
# when the input is tensor([91, 48, 65, 62]) target is 1
# when the input is tensor([91, 48, 65, 62,  1]) target is 44
# when the input is tensor([91, 48, 65, 62,  1, 44]) target is 75
# when the input is tensor([91, 48, 65, 62,  1, 44, 75]) target is 72
# when the input is tensor([91, 48, 65, 62,  1, 44, 75, 72]) target is 67

# %%
for i in range(4):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
y
# Out:
# tensor([48, 65, 62,  1, 44, 75, 72, 67])
